# %%
from transformers import pipeline

camembert_fill_mask = pipeline("fill-mask", model="camembert-base")
results = camembert_fill_mask("Le camembert est <mask> :)")
# Out:
# /Users/yuxinliu/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
from transformers import CamembertTokenizer, CamembertForMaskedLM

tokenizer = CamembertTokenizer.from_pretrained("camembert-base")
model = CamembertForMaskedLM.from_pretrained("camembert-base")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import CamembertTokenizer, CamembertForMaskedLM
#       3 tokenizer = CamembertTokenizer.from_pretrained("camembert-base")
#       4 model = CamembertForMaskedLM.from_pretrained("camembert-base")
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:1767, in _LazyModule.__getattr__(self, name)
#    1765 elif name in self._class_to_module.keys():
#    1766     module = self._get_module(self._class_to_module[name])
# -> 1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#    1769     value = self._get_module(name)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:1766, in _LazyModule.__getattr__(self, name)
#    1764     value = Placeholder
#    1765 elif name in self._class_to_module.keys():
# -> 1766     module = self._get_module(self._class_to_module[name])
#    1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/import_utils.py:1778, in _LazyModule._get_module(self, module_name)
#    1776 def _get_module(self, module_name: str):
#    1777     try:
# -> 1778         return importlib.import_module("." + module_name, self.__name__)
#    1779     except Exception as e:
#    1780         raise RuntimeError(
#    1781             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1782             f" traceback):\n{e}"
#    1783         ) from e
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/camembert/modeling_camembert.py:43
#      29 from ...modeling_attn_mask_utils import (
#      30     _prepare_4d_attention_mask_for_sdpa,
#      31     _prepare_4d_causal_attention_mask_for_sdpa,
#      32 )
#      33 from ...modeling_outputs import (
#      34     BaseModelOutputWithPastAndCrossAttentions,
#      35     BaseModelOutputWithPoolingAndCrossAttentions,
#    (...)
#      41     TokenClassifierOutput,
#      42 )
# ---> 43 from ...modeling_utils import PreTrainedModel
#      44 from ...pytorch_utils import apply_chunking_to_forward, find_pruneable_heads_and_indices, prune_linear_layer
#      45 from ...utils import (
#      46     add_code_sample_docstrings,
#      47     add_start_docstrings,
#    (...)
#      51     replace_return_docstrings,
#      52 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:48
#      46 from .generation import GenerationConfig, GenerationMixin
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
# ---> 48 from .loss.loss_utils import LOSS_MAPPING
#      49 from .pytorch_utils import (  # noqa: F401
#      50     Conv1D,
#      51     apply_chunking_to_forward,
#    (...)
#      57     prune_linear_layer,
#      58 )
#      59 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/loss/loss_utils.py:19
#      16 import torch.nn as nn
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#      21 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/loss/loss_deformable_detr.py:4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#       6 from .loss_for_object_detection import (
#       7     HungarianMatcher,
#       8     ImageLoss,
#    (...)
#      11     sigmoid_focal_loss,
#      12 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/image_transforms.py:50
#      47     import torch
#      49 if is_tf_available():
# ---> 50     import tensorflow as tf
#      52 if is_flax_available():
#      53     import jax.numpy as jnp
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/pywrap_tensorflow.py:37
#      32 from tensorflow.python.platform import self_check
#      34 # TODO(mdan): Cleanup antipattern: import for side effects.
#      35
#      36 # Perform pre-load sanity checks in order to produce a more actionable error.
# ---> 37 self_check.preload_check()
#      39 # pylint: disable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#      41 try:
#      42   # This import is expected to fail if there is an explicit shared object
#      43   # dependency (with_framework_lib=true), since we do not need RTLD_GLOBAL.
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/platform/self_check.py:63, in preload_check()
#      50       raise ImportError(
#      51           "Could not find the DLL(s) %r. TensorFlow requires that these DLLs "
#      52           "be installed in a directory that is named in your %%PATH%% "
#    (...)
#      56           "https://support.microsoft.com/help/2977003/the-latest-supported-visual-c-downloads"
#      57           % " or ".join(missing))
#      58 else:
#      59   # Load a library that performs CPU feature guard checking.  Doing this here
#      60   # as a preload check makes it more likely that we detect any CPU feature
#      61   # incompatibilities before we trigger them (which would typically result in
#      62   # SIGILL).
# ---> 63   from tensorflow.python.platform import _pywrap_cpu_feature_guard
#      64   _pywrap_cpu_feature_guard.InfoAboutUnusedCPUFeatures()
#
# KeyboardInterrupt:

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("camembert-base")
model = AutoModelForMaskedLM.from_pretrained("camembert-base")
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from huggingface_hub import notebook_login
notebook_login()
# or in terminal

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    "bert-finetuned-mrpc", save_strategy="epoch", push_to_hub=True
)
# Out:
# /Users/yuxinliu/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
from transformers import AutoModelForMaskedLM, AutoTokenizer

checkpoint = "camembert-base"

model = AutoModelForMaskedLM.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.push_to_hub("dummy-model")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Uesing/dummy-model/commit/b7e6f6b5cb0046446badf84052042da2a504ab8d', commit_message='Upload CamembertForMaskedLM', commit_description='', oid='b7e6f6b5cb0046446badf84052042da2a504ab8d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Uesing/dummy-model', endpoint='https://huggingface.co', repo_type='model', repo_id='Uesing/dummy-model'), pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("dummy-model")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Uesing/dummy-model/commit/3b96fcb5eef66b1549acf1ac226b5f6353d0ea4e', commit_message='Upload tokenizer', commit_description='', oid='3b96fcb5eef66b1549acf1ac226b5f6353d0ea4e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Uesing/dummy-model', endpoint='https://huggingface.co', repo_type='model', repo_id='Uesing/dummy-model'), pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("dummy-model", organization="huggingface")
# Out:
# /Users/yuxinliu/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:731: UserWarning: The `organization` argument is deprecated and will be removed in v5 of Transformers. Set your organization directly in the `repo_id` passed instead (`repo_id={organization}/{model_id}`).
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:403, in hf_raise_for_status(response, endpoint_name)
#     402 try:
# --> 403     response.raise_for_status()
#     404 except HTTPError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tokenizer.push_to_hub("dummy-model", organization="huggingface")
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:933, in PushToHubMixin.push_to_hub(self, repo_id, use_temp_dir, commit_message, private, token, max_shard_size, create_pr, safe_serialization, revision, commit_description, tags, **deprecated_kwargs)
#     930 repo_url = deprecated_kwargs.pop("repo_url", None)
#     931 organization = deprecated_kwargs.pop("organization", None)
# --> 933 repo_id = self._create_repo(
#     934     repo_id, private=private, token=token, repo_url=repo_url, organization=organization
#     935 )
#     937 # Create a new empty model card and eventually tag it
#     938 model_card = create_and_tag_model_card(
#     939     repo_id, tags, token=token, ignore_metadata_errors=ignore_metadata_errors
#     940 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:740, in PushToHubMixin._create_repo(self, repo_id, private, token, repo_url, organization)
#     737             repo_id = repo_id.split("/")[-1]
#     738         repo_id = f"{organization}/{repo_id}"
# --> 740 url = create_repo(repo_id=repo_id, token=token, private=private, exist_ok=True)
#     741 return url.repo_id
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/hf_api.py:3773, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3771         return RepoUrl(f"{self.endpoint}/{repo_type}/{repo_id}")
#    3772     except HfHubHTTPError:
# -> 3773         raise err
#    3774 else:
#    3775     raise
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/hf_api.py:3760, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3757     break
#    3759 try:
# -> 3760     hf_raise_for_status(r)
#    3761 except HTTPError as err:
#    3762     if exist_ok and err.response.status_code == 409:
#    3763         # Repo already exists and `exist_ok=True`
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:467, in hf_raise_for_status(response, endpoint_name)
#     461 elif response.status_code == 403:
#     462     message = (
#     463         f"\n\n{response.status_code} Forbidden: {error_message}."
#     464         + f"\nCannot access content at: {response.url}."
#     465         + "\nMake sure your token has the correct permissions."
#     466     )
# --> 467     raise _format(HfHubHTTPError, message, response) from e
#     469 elif response.status_code == 416:
#     470     range_header = response.request.headers.get("Range")
#
# HfHubHTTPError: (Request ID: Root=1-6a023472-5e9844497c829a5561c73d52;a143b4f7-a34e-41d6-b9f2-4186220ee91b)
#
# 403 Forbidden: You don't have the rights to create a model under the namespace "huggingface".
# Cannot access content at: https://huggingface.co/api/repos/create.
# Make sure your token has the correct permissions.

# %%
model.push_to_hub("dummy-model", organization="huggingface", use_auth_token="<TOKEN>.")
# Out:
# /Users/yuxinliu/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:894: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:403, in hf_raise_for_status(response, endpoint_name)
#     402 try:
# --> 403     response.raise_for_status()
#     404 except HTTPError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.push_to_hub("dummy-model", organization="huggingface", use_auth_token="<TOKEN>.")
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:3079, in PreTrainedModel.push_to_hub(self, *args, **kwargs)
#    3077 if tags:
#    3078     kwargs["tags"] = tags
# -> 3079 return super().push_to_hub(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:933, in PushToHubMixin.push_to_hub(self, repo_id, use_temp_dir, commit_message, private, token, max_shard_size, create_pr, safe_serialization, revision, commit_description, tags, **deprecated_kwargs)
#     930 repo_url = deprecated_kwargs.pop("repo_url", None)
#     931 organization = deprecated_kwargs.pop("organization", None)
# --> 933 repo_id = self._create_repo(
#     934     repo_id, private=private, token=token, repo_url=repo_url, organization=organization
#     935 )
#     937 # Create a new empty model card and eventually tag it
#     938 model_card = create_and_tag_model_card(
#     939     repo_id, tags, token=token, ignore_metadata_errors=ignore_metadata_errors
#     940 )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:740, in PushToHubMixin._create_repo(self, repo_id, private, token, repo_url, organization)
#     737             repo_id = repo_id.split("/")[-1]
#     738         repo_id = f"{organization}/{repo_id}"
# --> 740 url = create_repo(repo_id=repo_id, token=token, private=private, exist_ok=True)
#     741 return url.repo_id
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/hf_api.py:3760, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3757     break
#    3759 try:
# -> 3760     hf_raise_for_status(r)
#    3761 except HTTPError as err:
#    3762     if exist_ok and err.response.status_code == 409:
#    3763         # Repo already exists and `exist_ok=True`
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:476, in hf_raise_for_status(response, endpoint_name)
#     472     raise _format(HfHubHTTPError, message, response) from e
#     474 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     475 # as well (request id and/or server error message)
# --> 476 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-6a0234ae-238df25619bc7bfa0ce4583c;8f7a5d63-067d-4b5d-8234-4337a956d729)
#
# Invalid username or password.

# %%
from huggingface_hub import create_repo

create_repo("dummy-model")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:403, in hf_raise_for_status(response, endpoint_name)
#     402 try:
# --> 403     response.raise_for_status()
#     404 except HTTPError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 from huggingface_hub import create_repo
# ----> 3 create_repo("dummy-model")
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/hf_api.py:3760, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3757     break
#    3759 try:
# -> 3760     hf_raise_for_status(r)
#    3761 except HTTPError as err:
#    3762     if exist_ok and err.response.status_code == 409:
#    3763         # Repo already exists and `exist_ok=True`
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:476, in hf_raise_for_status(response, endpoint_name)
#     472     raise _format(HfHubHTTPError, message, response) from e
#     474 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     475 # as well (request id and/or server error message)
# --> 476 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create (Request ID: Root=1-6a023582-0a87ea2d6170de81287131b2;d7b3f3d5-33d0-45c3-9845-fd08572cd9c4)
#
# You already created this model repo: Uesing/dummy-model

# %%
from huggingface_hub import create_repo
create_repo("dummy-model", organization="huggingface")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from huggingface_hub import create_repo
# ----> 2 create_repo("dummy-model", organization="huggingface")
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# TypeError: HfApi.create_repo() got an unexpected keyword argument 'organization'

# %%
from huggingface_hub import upload_file

upload_file(
    "<path_to_file>/config.json",
    path_in_repo="config.json",
    repo_id="<namespace>/dummy-model"
)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from huggingface_hub import upload_file
# ----> 3 upload_file(
#       4     "<path_to_file>/config.json",
#       5     path_in_repo="config.json",
#       6     repo_id="<namespace>/dummy-model"
#       7 )
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:160, in validate_repo_id(repo_id)
#     154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
# --> 160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars, '-', '_' or '.'."
#     162         " The name cannot start or end with '-' or '.' and the maximum length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#     166 if "--" in repo_id or ".." in repo_id:
#     167     raise HFValidationError(f"Cannot have -- or .. in repo_id: '{repo_id}'.")
#
# HFValidationError: Repo id must use alphanumeric chars, '-', '_' or '.'. The name cannot start or end with '-' or '.' and the maximum length is 96: '<namespace>/dummy-model'.

# %%
from huggingface_hub import Repository

repo = Repository("<path_to_dummy_folder>", clone_from="<namespace>/dummy-model")

# %%
model.save_pretrained("<path_to_dummy_folder>")
tokenizer.save_pretrained("<path_to_dummy_folder>")

# %%
# repo.git_add()
# repo.git_commit("Add model and tokenizer files")
# repo.git_push()
model.push_to_hub("Uesing/dummy-model")
tokenizer.push_to_hub("Uesing/dummy-model")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/Uesing/dummy-model/commit/3b96fcb5eef66b1549acf1ac226b5f6353d0ea4e', commit_message='Upload tokenizer', commit_description='', oid='3b96fcb5eef66b1549acf1ac226b5f6353d0ea4e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Uesing/dummy-model', endpoint='https://huggingface.co', repo_type='model', repo_id='Uesing/dummy-model'), pr_revision=None, pr_num=None)
